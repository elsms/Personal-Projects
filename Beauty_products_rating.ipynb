# %% [markdown]
# <a href="https://colab.research.google.com/github/elsms/Personal-Projects/blob/main/Beauty_products_rating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Beauty Products Ranking Exercise

# %% [markdown]
# Dataset downloaded from https://www.kaggle.com/datasets/shivd24coder/cosmetic-brand-products-dataset

# %%
data = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#      id      brand                  name  price price_sign currency  \
# 0  1048  colourpop         Lippie Pencil    5.0          $      CAD
# 1  1047  colourpop           Blotted Lip    5.5          $      CAD
# 2  1046  colourpop           Lippie Stix    5.5          $      CAD
# 3  1045  colourpop  No Filter Foundation   12.0          $      CAD
# 4  1044      boosh              Lipstick   26.0          $      CAD
#
#                                           image_link  \
# 0  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 1  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 2  https://cdn.shopify.com/s/files/1/1338/0845/co...
# 3  https://cdn.shopify.com/s/files/1/1338/0845/pr...
# 4  https://cdn.shopify.com/s/files/1/1016/3243/pr...
#
#                                         product_link  \
# 0    https://colourpop.com/collections/lippie-pencil
# 1  https://colourpop.com/collections/lippie-stix?...
# 2      https://colourpop.com/collections/lippie-stix
# ...

# %%
data.columns
# Out:
# Index(['id', 'brand', 'name', 'price', 'price_sign', 'currency', 'image_link',
#        'product_link', 'website_link', 'description', 'rating', 'category',
#        'product_type', 'tag_list', 'created_at', 'updated_at',
#        'product_api_url', 'api_featured_image', 'product_colors'],
#       dtype='object')

# %%
# data.iloc[:,4].values
# data.iloc[:, 5].values

# %%
d = data.iloc[:,[0,1,2,10,11]]

# %%
drating = d[d.iloc[:,3].notna()]
#drating
df = drating.iloc[:,[0,1,2,3]]
#df

# %%
df.set_index("id", inplace=True)
df
# Out:
#                   brand                                               name  \
# id
# 508                 nyx                   NYX Mosaic Powder Blush Paradise
# 505           annabelle                 Annabelle Biggy Bronzer Haute Gold
# 503  physicians formula  Physicians Formula Super BB InstaReady Filter ...
# 495          maybelline  Maybelline Face Studio Master Hi-Light Light B...
# 493  physicians formula  Physicians Formula Bronze Booster Glow-Boostin...
# ..                  ...                                                ...
# 5              pacifica  Pacifica Stellar Gaze Length & Strength Minera...
# 4    physicians formula    Physicians Formula Organic Wear FakeOut Mascara
# 3    physicians formula  Physicians Formula Organic Wear Lash Boosting ...
# 2                   NaN                  L' Oreal Paris Voluminous Mascara
# 1            pure anada                         Pure Anada Natural Mascara
#
#      rating
# id
# 508     5.0
# 505     5.0
# 503     4.0
# ...
